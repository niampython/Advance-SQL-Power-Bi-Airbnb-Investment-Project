# %%
import os
import pandas as pd
import sqlalchemy as sa

#-----------------------------------------
# CONFIG
#-----------------------------------------
root_path = r"C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya"

  # folder that contains the 5 subfolders
folders = ["Kiambu", "Nakuru", "Nairobi", "Mombasa", "Kisumu"]

# SQL Server connection string
connection_string = (
    "mssql+pyodbc://@LPJZ5KFY3/Airbnb_data"
    "?driver=ODBC+Driver+17+for+SQL+Server"
)


engine = sa.create_engine(connection_string)

#-----------------------------------------
# STEP 1: Build a dictionary of suffixes
#-----------------------------------------
suffix_groups = {}

for folder in folders:
    folder_path = os.path.join(root_path, folder)

    for file in os.listdir(folder_path):
        if file.endswith(".csv"):

            # Extract suffix: everything after the first underscore
            suffix = file.split("_", 1)[1]   # keeps "occupancy_last_12_month.csv"

            # Add to dictionary
            if suffix not in suffix_groups:
                suffix_groups[suffix] = []

            suffix_groups[suffix].append(os.path.join(folder_path, file))

print("Detected unified suffixes:", list(suffix_groups.keys()))

#-----------------------------------------
# STEP 2: Union files by suffix
#-----------------------------------------
for suffix, filepaths in suffix_groups.items():

    print(f"\nUnioning group: {suffix}")
    df_list = []

    for file in filepaths:
        print(f"   Reading: {file}")
        try:
            df = pd.read_csv(file)

            # CLEAN HEADER NAMES
            df.columns = df.columns.str.strip()             # remove trailing spaces
            df.columns = df.columns.str.replace(" ", "_")   # normalize
            df.columns = df.columns.str.replace("-", "_")
            df.columns = df.columns.str.replace("/", "_")

            df_list.append(df)

        except Exception as e:
            print(f"   ERROR reading {file}: {e}")
            continue

    if not df_list:
        print("   No valid CSV files. Skipping.")
        continue

    # Union
    union_df = pd.concat(df_list, ignore_index=True)

    # Clean final columns again to ensure uniqueness
    union_df.columns = union_df.columns.str.strip().str.replace(" ", "_")

    table_name = os.path.splitext(suffix)[0].replace(".", "_")

    print(f"   Loading into SQL table: {table_name}")

    union_df.to_sql(
        table_name,
        engine,
        if_exists="replace",
        index=False,
        chunksize=5000
    )
print("\nAll files unioned and loaded to SQL Server successfully!")
# Out:
# Detected unified suffixes: ['occupancyBedrooms_last_12_month.csv', 'occupancyDemand_last_12_month.csv', 'occupancyFuture_next_30_days.csv', 'occupancyLength_last_12_month.csv', 'occupancy_last_12_month.csv', 'rateByBedroom_last_12_month.csv', 'rateByDailyAverage_last_12_month.csv', 'rateByDay_last_12_month.csv', 'rateByPriceTier_last_12_month.csv', 'rateFuture_next_180_days.csv', 'revenueAverage_last_12_month.csv', 'revenueByBedroom_last_12_month.csv', 'revenueByPercentile_last_12_month.csv', 'revenueByRealEstateType_last_12_month.csv', 'revparHighestInYear_last_12_month.csv', 'revparInAdvance_last_12_month.csv', 'revpar_last_12_month.csv', 'occupancyBedrooms_last_12_month (1).csv', 'occupancyFuture_next_30_days (1).csv']
#
# Unioning group: occupancyBedrooms_last_12_month.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Kiambu\Kiambu_occupancyBedrooms_last_12_month.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Nakuru\Nakuru_occupancyBedrooms_last_12_month.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Nairobi\Nairobi_occupancyBedrooms_last_12_month.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Kisumu\Kisumu_occupancyBedrooms_last_12_month.csv
#    Loading into SQL table: occupancyBedrooms_last_12_month
#
# Unioning group: occupancyDemand_last_12_month.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Kiambu\Kiambu_occupancyDemand_last_12_month.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Nakuru\Nakuru_occupancyDemand_last_12_month.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Nairobi\Nairobi_occupancyDemand_last_12_month.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Mombasa\Mombasa_occupancyDemand_last_12_month.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Kisumu\Kisumu_occupancyDemand_last_12_month.csv
#    Loading into SQL table: occupancyDemand_last_12_month
#
# Unioning group: occupancyFuture_next_30_days.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Kiambu\Kiambu_occupancyFuture_next_30_days.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Nakuru\Nakuru_occupancyFuture_next_30_days.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Nairobi\Nairobi_occupancyFuture_next_30_days.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Kisumu\Kisumu_occupancyFuture_next_30_days.csv
#    Loading into SQL table: occupancyFuture_next_30_days
#
# Unioning group: occupancyLength_last_12_month.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Kiambu\Kiambu_occupancyLength_last_12_month.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Nakuru\Nakuru_occupancyLength_last_12_month.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Nairobi\Nairobi_occupancyLength_last_12_month.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Mombasa\Mombasa_occupancyLength_last_12_month.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Kisumu\Kisumu_occupancyLength_last_12_month.csv
#    Loading into SQL table: occupancyLength_last_12_month
#
# Unioning group: occupancy_last_12_month.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Kiambu\Kiambu_occupancy_last_12_month.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Nakuru\Nakuru_occupancy_last_12_month.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Nairobi\Nairobi_occupancy_last_12_month.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Mombasa\Mombasa_occupancy_last_12_month.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Kisumu\Kisumu_occupancy_last_12_month.csv
#    Loading into SQL table: occupancy_last_12_month
#
# Unioning group: rateByBedroom_last_12_month.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Kiambu\Kiambu_rateByBedroom_last_12_month.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Nakuru\Nakuru_rateByBedroom_last_12_month.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Nairobi\Nairobi_rateByBedroom_last_12_month.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Mombasa\Mombasa_rateByBedroom_last_12_month.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Kisumu\Kisumu_rateByBedroom_last_12_month.csv
#    Loading into SQL table: rateByBedroom_last_12_month
#
# Unioning group: rateByDailyAverage_last_12_month.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Kiambu\Kiambu_rateByDailyAverage_last_12_month.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Nakuru\Nakuru_rateByDailyAverage_last_12_month.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Nairobi\Nairobi_rateByDailyAverage_last_12_month.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Mombasa\Mombasa_rateByDailyAverage_last_12_month.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Kisumu\Kisumu_rateByDailyAverage_last_12_month.csv
#    Loading into SQL table: rateByDailyAverage_last_12_month
#
# Unioning group: rateByDay_last_12_month.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Kiambu\Kiambu_rateByDay_last_12_month.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Nakuru\Nakuru_rateByDay_last_12_month.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Nairobi\Nairobi_rateByDay_last_12_month.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Mombasa\Mombasa_rateByDay_last_12_month.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Kisumu\Kisumu_rateByDay_last_12_month.csv
#    Loading into SQL table: rateByDay_last_12_month
#
# Unioning group: rateByPriceTier_last_12_month.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Kiambu\Kiambu_rateByPriceTier_last_12_month.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Nakuru\Nakuru_rateByPriceTier_last_12_month.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Nairobi\Nairobi_rateByPriceTier_last_12_month.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Mombasa\Mombasa_rateByPriceTier_last_12_month.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Kisumu\Kisumu_rateByPriceTier_last_12_month.csv
#    Loading into SQL table: rateByPriceTier_last_12_month
#
# Unioning group: rateFuture_next_180_days.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Kiambu\Kiambu_rateFuture_next_180_days.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Nakuru\Nakuru_rateFuture_next_180_days.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Nairobi\Nairobi_rateFuture_next_180_days.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Mombasa\Mombasa_rateFuture_next_180_days.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Kisumu\Kisumu_rateFuture_next_180_days.csv
#    Loading into SQL table: rateFuture_next_180_days
#
# Unioning group: revenueAverage_last_12_month.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Kiambu\Kiambu_revenueAverage_last_12_month.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Nakuru\Nakuru_revenueAverage_last_12_month.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Nairobi\Nairobi_revenueAverage_last_12_month.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Mombasa\Mombasa_revenueAverage_last_12_month.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Kisumu\Kisumu_revenueAverage_last_12_month.csv
#    Loading into SQL table: revenueAverage_last_12_month
#
# Unioning group: revenueByBedroom_last_12_month.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Kiambu\Kiambu_revenueByBedroom_last_12_month.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Nakuru\Nakuru_revenueByBedroom_last_12_month.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Nairobi\Nairobi_revenueByBedroom_last_12_month.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Mombasa\Mombasa_revenueByBedroom_last_12_month.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Kisumu\Kisumu_revenueByBedroom_last_12_month.csv
#    Loading into SQL table: revenueByBedroom_last_12_month
#
# Unioning group: revenueByPercentile_last_12_month.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Kiambu\Kiambu_revenueByPercentile_last_12_month.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Nakuru\Nakuru_revenueByPercentile_last_12_month.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Nairobi\Nairobi_revenueByPercentile_last_12_month.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Mombasa\Mombasa_revenueByPercentile_last_12_month.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Kisumu\Kisumu_revenueByPercentile_last_12_month.csv
#    Loading into SQL table: revenueByPercentile_last_12_month
#
# Unioning group: revenueByRealEstateType_last_12_month.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Kiambu\Kiambu_revenueByRealEstateType_last_12_month.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Nakuru\Nakuru_revenueByRealEstateType_last_12_month.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Nairobi\Nairobi_revenueByRealEstateType_last_12_month.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Mombasa\Mombasa_revenueByRealEstateType_last_12_month.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Kisumu\Kisumu_revenueByRealEstateType_last_12_month.csv
#    Loading into SQL table: revenueByRealEstateType_last_12_month
#
# Unioning group: revparHighestInYear_last_12_month.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Kiambu\Kiambu_revparHighestInYear_last_12_month.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Nakuru\Nakuru_revparHighestInYear_last_12_month.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Nairobi\Nairobi_revparHighestInYear_last_12_month.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Mombasa\Mombasa_revparHighestInYear_last_12_month.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Kisumu\Kisumu_revparHighestInYear_last_12_month.csv
#    Loading into SQL table: revparHighestInYear_last_12_month
#
# Unioning group: revparInAdvance_last_12_month.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Kiambu\Kiambu_revparInAdvance_last_12_month.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Nakuru\Nakuru_revparInAdvance_last_12_month.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Nairobi\Nairobi_revparInAdvance_last_12_month.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Mombasa\Mombasa_revparInAdvance_last_12_month.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Kisumu\Kisumu_revparInAdvance_last_12_month.csv
#    Loading into SQL table: revparInAdvance_last_12_month
#
# Unioning group: revpar_last_12_month.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Kiambu\Kiambu_revpar_last_12_month.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Nairobi\Nairobi_revpar_last_12_month.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Mombasa\Mombasa_revpar_last_12_month.csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Kisumu\Kisumu_revpar_last_12_month.csv
#    Loading into SQL table: revpar_last_12_month
#
# Unioning group: occupancyBedrooms_last_12_month (1).csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Mombasa\Mombasa_occupancyBedrooms_last_12_month (1).csv
#    Loading into SQL table: occupancyBedrooms_last_12_month (1)
#
# Unioning group: occupancyFuture_next_30_days (1).csv
#    Reading: C:\Users\Public\Documents\East Africa Airbnb Advance SQL-Power Bi Project\Kenya\Mombasa\Mombasa_occupancyFuture_next_30_days (1).csv
#    Loading into SQL table: occupancyFuture_next_30_days (1)
#
# All files unioned and loaded to SQL Server successfully!
